# %%
from __future__ import print_function
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
from scipy.stats import zscore
import seaborn as sns
import sys,os
import gzip
import ftplib
import re

# %%
def download_GEO_matrix(fname,ftppath,destination=os.getcwd(),ftp='ftp.ncbi.nlm.nih.gov'):
    ftp = ftplib.FTP(ftp)   
    ftp.login() 
    ftp.cwd(ftppath)
    #ftp.retrlines('LIST')
    file_handle = open(destination+"/"+fname, 'wb')
    ftp.retrbinary('RETR '+fname, file_handle.write)
    file_handle.close()
    ftp.quit()
    return destination+"/"+fname

def read_matrix(fname,index = "GSM"):
    df = {}
    with gzip.open(fname) as infile:
        for line in infile.readlines():
            if line.startswith("!"):
                line = line.rstrip().replace('"','').split("\t")
                line =  map(lambda x : x.rstrip().lstrip(),line)
                #print(line)
                if line[0] == '!Sample_title':
                    df["title"] = line[1:]
                if line[0] == '!Sample_geo_accession':
                    df["GSM"] = line[1:]
                if line[0] == '!Sample_source_name_ch1':
                    df["source"] = line[1:]
                if line[0] == '!Sample_characteristics_ch1':
                    if ":" in line[1]:
                        sep = ": "
                    elif "=" in line[1]:
                        sep = "= "
                    else:
                        pass
                    field = line[1].split(sep)[0]
                    df[field] = map(lambda x : x.replace(field+sep,"").rstrip().lstrip(),line[1:])
    df=pd.DataFrame.from_dict(df)
    df.set_index(index,drop=True,inplace=True)
    return df

# %% [markdown]
# ## GSE28796 - Docetaxel

# %%
tmp_dir = "/home/olya/SFU/Hossein/NEW_Project/raw_data/downloads/"
fpath = download_GEO_matrix("GSE28796_series_matrix.txt.gz",'/geo/series/GSE28nnn/GSE28796/matrix/'
                    ,destination=tmp_dir)
df = read_matrix(fpath)
df = df.loc[:,["pathological complete response","replicate","sample"]]
df.columns = ["pathological complete response","replicate","patient"]
df["drug"] = "Docetaxel"
df.index.name = "sample_name"
df["response"] = "R"
df.loc[df["pathological complete response"] == "yes","response"] = "S"
df = df.loc[:,["drug","response","patient","replicate","pathological complete response"]]
df.to_csv("../raw_data/response/GSE28796_response.tsv",sep ="\t")
df
# Out:
#                   drug response patient replicate  \
# sample_name
# GSM713198    Docetaxel        R       1         1
# GSM713199    Docetaxel        R       1         2
# GSM713200    Docetaxel        R       2         1
# GSM713201    Docetaxel        R       2         2
# GSM713202    Docetaxel        R       3         1
# GSM713203    Docetaxel        R       3         2
# GSM713204    Docetaxel        S       4         1
# GSM713205    Docetaxel        S       4         2
# GSM713206    Docetaxel        R       5         1
# GSM713207    Docetaxel        R       5         2
# GSM713208    Docetaxel        R       6         1
# GSM713209    Docetaxel        R       6         2
# GSM713210    Docetaxel        R       7         1
# GSM713211    Docetaxel        R       7         2
# GSM713212    Docetaxel        R       8         1
# GSM713213    Docetaxel        R       8         2
# GSM713214    Docetaxel        R       9         1
# GSM713215    Docetaxel        R       9         2
# GSM713216    Docetaxel        R      10         1
# GSM713217    Docetaxel        R      10         2
# GSM713218    Docetaxel        R      11         1
# GSM713219    Docetaxel        R      11         2
# GSM713220    Docetaxel        R      12         1
# GSM713221    Docetaxel        R      12         2
#
#             pathological complete response
# sample_name
# GSM713198                               no
# GSM713199                               no
# GSM713200                               no
# GSM713201                               no
# GSM713202                               no
# GSM713203                               no
# GSM713204                              yes
# GSM713205                              yes
# GSM713206                               no
# GSM713207                               no
# GSM713208                               no
# GSM713209                               no
# GSM713210                               no
# GSM713211                               no
# GSM713212                               no
# GSM713213                               no
# GSM713214                               no
# GSM713215                               no
# GSM713216                               no
# GSM713217                               no
# GSM713218                               no
# GSM713219                               no
# GSM713220                               no
# GSM713221                               no

# %% [markdown]
# ## Paclitaxel
#  * GSE15622 (Paclitaxel pre-treatment)
#  * GSE22513

# %%
fpath = download_GEO_matrix("GSE15622_series_matrix.txt.gz",'/geo/series/GSE15nnn/GSE15622/matrix/'
                    ,destination=tmp_dir)
df = read_matrix(fpath)
df= df.loc[df["treatment"] == "Paclitaxel",:]
df["drug"] = "Paclitaxel"
df.index.name = "sample_name"
df.shape
df = df.loc[df["title"].str.contains("pre-treatment"), :]
df["patient"] = df["title"].apply(lambda x : x.split(",")[0])
df.loc[df["clinical group"]=="pre_pacli_resist","response"] = "R"
df.loc[df["clinical group"]=="pre_pacli_sens","response"] = "S"
df = df.loc[:,["drug","patient","response","clinical group","ca-125 coefficient"]]
df.to_csv("../raw_data/response/GSE15622_response.tsv",sep ="\t")
df
# Out:
#                    drug     patient response    clinical group  \
# sample_name
# GSM391038    Paclitaxel  Patient 12        R  pre_pacli_resist
# GSM391039    Paclitaxel  Patient 14        R  pre_pacli_resist
# GSM391040    Paclitaxel  Patient 15        S    pre_pacli_sens
# GSM391041    Paclitaxel  Patient 16        S    pre_pacli_sens
# GSM391042    Paclitaxel  Patient 19        R  pre_pacli_resist
# GSM391043    Paclitaxel  Patient 24        S    pre_pacli_sens
# GSM391044    Paclitaxel  Patient 27        R  pre_pacli_resist
# GSM391045    Paclitaxel  Patient 28        R  pre_pacli_resist
# GSM391046    Paclitaxel   Patient 2        S    pre_pacli_sens
# GSM391047    Paclitaxel  Patient 33        R  pre_pacli_resist
# GSM391048    Paclitaxel  Patient 34        S    pre_pacli_sens
# GSM391049    Paclitaxel  Patient 38        R  pre_pacli_resist
# GSM391050    Paclitaxel  Patient 39        S    pre_pacli_sens
# GSM391051    Paclitaxel  Patient 41        S    pre_pacli_sens
# GSM391052    Paclitaxel  Patient 43        S    pre_pacli_sens
# GSM391053    Paclitaxel  Patient 44        S    pre_pacli_sens
# GSM391054    Paclitaxel   Patient 5        S    pre_pacli_sens
# GSM391055    Paclitaxel   Patient 7        S    pre_pacli_sens
# GSM391056    Paclitaxel   Patient 8        S    pre_pacli_sens
# GSM391057    Paclitaxel   Patient 9        S    pre_pacli_sens
#
#             ca-125 coefficient
# sample_name
# GSM391038        -0.0421121970
# GSM391039         0.2001034690
# GSM391040        -0.9864544140
# GSM391041        -1.4979386590
# GSM391042        -0.2875815110
# GSM391043        -0.5330089410
# GSM391044        -0.4785749740
# GSM391045        -0.2861935530
# GSM391046        -0.8195863170
# GSM391047         0.2679183170
# GSM391048        -0.9518417360
# GSM391049        -0.3116701210
# GSM391050        -1.6925410650
# GSM391051        -0.8964856000
# GSM391052        -1.5101890540
# GSM391053        -1.3577411230
# GSM391054        -1.5429675790
# GSM391055        -0.6524794240
# GSM391056        -1.3307932560
# GSM391057        -1.2553998570

# %%
fpath = download_GEO_matrix("GSE22513_series_matrix.txt.gz",'/geo/series/GSE22nnn/GSE22513/matrix/'
                    ,destination=tmp_dir)
df = read_matrix(fpath)
df["drug"] = "Paclitaxel"
df["title"] = df["title"].apply(lambda x : x.replace("non-pCR breast biopsy, ",""))
df["title"] = df["title"].apply(lambda x : x.replace("pCR breast biopsy, ",""))
df["patient"] = df["title"].apply(lambda x : x.split(" ")[1])
df["replicate"] = df["title"].apply(lambda x : x.split(" ")[3])
df.index.name = "sample_name"
df["response"] = "R"
df.loc[df["pathological complete response"] == "yes","response"] = "S"
df = df.loc[:,["drug", "response","patient","replicate","pathological complete response"]]
df.to_csv("../raw_data/response/GSE22513_response.tsv",sep ="\t")
df
# Out:
#                    drug response patient replicate  \
# sample_name
# GSM559042    Paclitaxel        R       1         1
# GSM559043    Paclitaxel        R       1         2
# GSM559044    Paclitaxel        R       2         1
# GSM559045    Paclitaxel        R       2         2
# GSM559046    Paclitaxel        R       3         1
# GSM559047    Paclitaxel        R       3         2
# GSM559048    Paclitaxel        R       4         1
# GSM559049    Paclitaxel        R       4         2
# GSM559050    Paclitaxel        R       5         1
# GSM559051    Paclitaxel        R       5         2
# GSM559052    Paclitaxel        R       6         1
# GSM559053    Paclitaxel        R       6         2
# GSM559054    Paclitaxel        R       8         1
# GSM559055    Paclitaxel        R       8         2
# GSM559056    Paclitaxel        R       9         1
# GSM559057    Paclitaxel        R       9         2
# GSM559058    Paclitaxel        R      10         1
# GSM559059    Paclitaxel        R      10         2
# GSM559060    Paclitaxel        R      13         1
# GSM559061    Paclitaxel        R      13         2
# GSM559062    Paclitaxel        S      15         1
# GSM559063    Paclitaxel        S      15         2
# GSM559064    Paclitaxel        S      16         1
# GSM559065    Paclitaxel        S      16         2
# GSM559066    Paclitaxel        S      18         1
# GSM559067    Paclitaxel        S      18         2
# GSM559068    Paclitaxel        S      19         1
# GSM559069    Paclitaxel        S      19         2
#
#             pathological complete response
# sample_name
# GSM559042                               no
# GSM559043                               no
# GSM559044                               no
# GSM559045                               no
# GSM559046                               no
# GSM559047                               no
# GSM559048                               no
# GSM559049                               no
# GSM559050                               no
# GSM559051                               no
# GSM559052                               no
# GSM559053                               no
# GSM559054                               no
# GSM559055                               no
# GSM559056                               no
# GSM559057                               no
# GSM559058                               no
# GSM559059                               no
# GSM559060                               no
# GSM559061                               no
# GSM559062                              yes
# GSM559063                              yes
# GSM559064                              yes
# GSM559065                              yes
# GSM559066                              yes
# GSM559067                              yes
# GSM559068                              yes
# GSM559069                              yes

# %% [markdown]
# ## Sorafenib
# * GSE109211
# * GSE31428 - table requred manual correction because columns were named differently

# %%
fpath = download_GEO_matrix("GSE109211_series_matrix.txt.gz",'/geo/series/GSE109nnn/GSE109211/matrix/'
                    ,destination=tmp_dir)
df = read_matrix(fpath)
df= df.loc[df["treatment"] == "Sor",:]
df["drug"] = "Sorafenib"
df = df.sort_values("title")
df["response"] = ""
df.loc[df["outcome"]=="non-responder","response"] = "R"
df.loc[df["outcome"]=="responder","response"] = "S"
df["sample"] = df["title"].apply(lambda x : x.replace(" FFPE sample",""))
df = df.loc[:,["drug","response","sample"]]
df.to_csv("../raw_data/response/GSE109211_response.tsv",sep ="\t")
df
# Out:
#                  drug response sample
# GSM
# GSM2935356  Sorafenib        R  BS101
# GSM2935413  Sorafenib        S  BS107
# GSM2935411  Sorafenib        S  BS117
# GSM2935320  Sorafenib        R  BS119
# GSM2935397  Sorafenib        R  BS129
# GSM2935333  Sorafenib        S  BS139
# GSM2935414  Sorafenib        R  BS149
# GSM2935407  Sorafenib        R  BS155
# GSM2935361  Sorafenib        S  BS157
# GSM2935416  Sorafenib        R  BS161
# GSM2935282  Sorafenib        S  BS165
# GSM2935386  Sorafenib        R  BS169
# GSM2935385  Sorafenib        S  BS183
# GSM2935281  Sorafenib        S  BS187
# GSM2935415  Sorafenib        S  BS195
# GSM2935394  Sorafenib        S  BS197
# GSM2935396  Sorafenib        S  BS205
# GSM2935362  Sorafenib        R  BS211
# GSM2935289  Sorafenib        R  BS213
# GSM2935370  Sorafenib        R  BS219
# GSM2935384  Sorafenib        R  BS241
# GSM2935313  Sorafenib        S  BS245
# GSM2935403  Sorafenib        R  BS247
# GSM2935401  Sorafenib        R  BS273
# GSM2935353  Sorafenib        R  BS277
# GSM2935395  Sorafenib        R  BS281
# GSM2935389  Sorafenib        R  BS283
# GSM2935338  Sorafenib        R  BS297
# GSM2935296  Sorafenib        R  BS299
# GSM2935402  Sorafenib        R  BS309
# ...               ...      ...    ...
# GSM2935331  Sorafenib        R  BS351
# GSM2935327  Sorafenib        R  BS363
# GSM2935351  Sorafenib        R  BS367
# GSM2935378  Sorafenib        R  BS369
# GSM2935330  Sorafenib        R  BS371
# GSM2935328  Sorafenib        R  BS379
# GSM2935301  Sorafenib        R  BS383
# GSM2935303  Sorafenib        R  BS389
# GSM2935297  Sorafenib        R  BS391
# GSM2935311  Sorafenib        R  BS399
# GSM2935305  Sorafenib        R  BS403
# GSM2935392  Sorafenib        S  BS409
# GSM2935405  Sorafenib        S  BS415
# GSM2935300  Sorafenib        S  BS419
# GSM2935285  Sorafenib        S  BS423
# GSM2935409  Sorafenib        S  BS429
# GSM2935323  Sorafenib        R  BS433
# GSM2935310  Sorafenib        S  BS435
# GSM2935406  Sorafenib        S  BS439
# GSM2935307  Sorafenib        R  BS443
# GSM2935314  Sorafenib        R  BS449
# GSM2935340  Sorafenib        R  BS451
# GSM2935302  Sorafenib        R  BS457
# GSM2935317  Sorafenib        R  BS461
# GSM2935304  Sorafenib        R  BS463
# GSM2935360  Sorafenib        R  BS465
# GSM2935355  Sorafenib        R  BS473
# GSM2935280  Sorafenib        S  BS481
# GSM2935288  Sorafenib        S  BS485
# GSM2935279  Sorafenib        S  BS493
#
# [67 rows x 3 columns]

# %%
fpath = download_GEO_matrix("GSE31428_series_matrix.txt.gz",'/geo/series/GSE31nnn/GSE31428/matrix/',destination=tmp_dir)
df = read_matrix(fpath)
df.to_csv("../raw_data/response/GSE31428_incorrect_columns.tsv",sep ="\t")
df = pd.read_csv("../raw_data/response/GSE31428_corrected_columns.tsv",sep ="\t",index_col=0)
cols = ['treatment',"8-week disease control (1=yes, 0=no)","pfsc (1=progressed; 0=not progressed)",'pfsm (month)',
        'randomization_date','biopsy site (grouped)',
        u'smoking_status',u'source', u'stage_at_diagnosis','gender','race','egfr index']
df["drug"] = "Sorafenib"
df['response']= "R"
df.loc[df["8-week disease control (1=yes, 0=no)"]==1,'response']= "S" 
BATTLE_trial_core biopsy_chemorefractory non-s...
# GSM780639  BATTLE_trial_core biopsy_chemorefractory non-s...
# GSM780640  BATTLE_trial_core biopsy_chemorefractory non-s...
#
#           stage_at_diagnosis  gender                    race  egfr index
# GSM
# GSM677317                 IV    Male                   White        0.21
# GSM677322               IIIB    Male                   White        1.13
# GSM677333                 IV    Male                   White        0.35
# GSM677335                 IV    Male                   White       -0.89
# GSM677336                 IV  Female                   White       -0.59
# GSM677337                 IV  Female                   White       -1.77
# GSM677338                 IV    Male                   White        1.01
# GSM780611                 IV  Female                   White        0.26
# GSM780612                 IV  Female                   White        1.17
# GSM780613                 IV  Female                   White        0.87
# GSM780614                 IV    Male                   White       -0.52
# GSM780615                 IV  Female                   White       -0.27
# GSM780616                 IV    Male                   White        0.89
# GSM780617               IIIB  Female  BlackOrAfricanAmerican       -0.96
# GSM780618                 IV  Female                   White        0.89
# GSM780619               IIIB  Female  BlackOrAfricanAmerican       -0.28
# GSM780620                 IV    Male                   White       -0.09
# GSM780621                 IV    Male                   White        0.97
# GSM780622               IIIB    Male                   White        0.84
# GSM780623               IIIA    Male                   White       -0.31
# GSM780624               IIIB  Female                   White       -0.52
# GSM780625                 IV    Male                   White       -1.33
# GSM780626               IIIB  Female                   White        1.22
# GSM780627                 IV    Male                   White        0.92
# GSM780628                 IV  Female                   White        1.10
# GSM780629                 IB  Female                   White       -0.02
# GSM780630                 IV    Male                   White       -0.24
# GSM780631                 IV    Male                   White        1.24
# GSM780632                IIB    Male                   White        0.00
# GSM780633                 IV  Female                   Asian        0.31
# GSM780634                 IV  Female                   White        1.10
# GSM780635                 IV    Male                   White        0.63
# GSM780636                 IV    Male                   White        1.26
# GSM780637                 IV  Female                   White        0.81
# GSM780638                 IV    Male                   Asian        1.05
# GSM780639                 IV    Male                   White       -0.49
# GSM780640                IIB    Male                   White        0.04

# %% [markdown]
# ## Bortezomib
# * GSE55145

# %%
fpath = download_GEO_matrix("GSE55145_series_matrix.txt.gz",'/geo/series/GSE55nnn/GSE55145/matrix/'
                    ,destination=tmp_dir)
df = read_matrix(fpath)
df["drug"] = "Bortezomib"
df["response"] = "S" # S = 39 (8 RCEP + 6 CR + 10 RCIF +15 TBRP)
# R = 28 (12 Prog + 6 RMin + 10 stable)
df.loc[df["post-induction (bortezomib) treatment response"] == "Prog (Progressive disease, no treatment response)","response"] = "R"
df.loc[df["post-induction (bortezomib) treatment response"] == "RMin (Minimal treatment response)","response"] = "R"
df.loc[df["post-induction (bortezomib) treatment response"] == "stable (stable disease, no treatment response)","response"] = "R"
df = df.loc[:,["drug","response",'microarray_batch', u'post-induction (bortezomib) treatment response',
       u'source', u'title']] 
df.to_csv("../raw_data/response/GSE55145_response.tsv",sep ="\t")
df
# Out:
#                   drug response microarray_batch  \
# GSM
# GSM1336382  Bortezomib        R                1
# GSM1336383  Bortezomib        R                1
# GSM1336384  Bortezomib        S                1
# GSM1336385  Bortezomib        R                1
# GSM1336386  Bortezomib        R                1
# GSM1336387  Bortezomib        S                1
# GSM1336388  Bortezomib        S                1
# GSM1336389  Bortezomib        R                1
# GSM1336390  Bortezomib        S                1
# GSM1336391  Bortezomib        R                1
# GSM1336392  Bortezomib        S                1
# GSM1336393  Bortezomib        R                1
# GSM1336394  Bortezomib        S                1
# GSM1336395  Bortezomib        R                1
# GSM1336396  Bortezomib        S                1
# GSM1336397  Bortezomib        S                1
# ...                                                       ...
# GSM1336419  CR un (Complete treatment, other than RCIF or ...
# GSM1336420  TBRP (VGPR or very good partial treatment resp...
# GSM1336421  Prog (Progressive disease, no treatment response)
# GSM1336422  CR un (Complete treatment, other than RCIF or ...
# GSM1336423     stable (stable disease, no treatment response)
# GSM1336424  Prog (Progressive disease, no treatment response)
# GSM1336425  TBRP (VGPR or very good partial treatment resp...
# GSM1336426  CR un (Complete treatment, other than RCIF or ...
# GSM1336427  Prog (Progressive disease, no treatment response)
# GSM1336428  TBRP (VGPR or very good partial treatment resp...
# GSM1336429     stable (stable disease, no treatment response)
# GSM1336430  CR un (Complete treatment, other than RCIF or ...
# GSM1336431     stable (stable disease, no treatment response)
# GSM1336432  TBRP (VGPR or very good partial treatment resp...
# GSM1336433  CR un (Complete treatment, other than RCIF or ...
# GSM1336434  TBRP (VGPR or very good partial treatment resp...
# GSM1336435  TBRP (VGPR or very good partial treatment resp...
# GSM1336436  Prog (Progressive disease, no treatment response)
# GSM1336437  TBRP (VGPR or very good partial treatment resp...
# GSM1336438     stable (stable disease, no treatment response)
# GSM1336439  TBRP (VGPR or very good partial treatment resp...
# GSM1336440     stable (stable disease, no treatment response)
# GSM1336441  TBRP (VGPR or very good partial treatment resp...
# GSM1336442  TBRP (VGPR or very good partial treatment resp...
# GSM1336443     stable (stable disease, no treatment response)
# GSM1336444  CR un (Complete treatment, other than RCIF or ...
# GSM1336445  Prog (Progressive disease, no treatment response)
# GSM1336446  TBRP (VGPR or very good partial treatment resp...
# GSM1336447  TBRP (VGPR or very good partial treatment resp...
# GSM1336448  Prog (Progressive disease, no treatment response)
#
#                                                        source  \
# GSM
# GSM1336382  CD-138 purified plasma cells from a newly diag...
# GSM1336383  CD-138 purified plasma cells from a newly diag...
# GSM1336384  CD-138 purified plasma cells from a newly diag...
# GSM1336385  CD-138 purified plasma cells from a newly diag...
# GSM1336386  CD-138 purified plasma cells from a newly diag...
# GSM1336387  CD-138 purified plasma cells from a newly diag...
# GSM1336388  CD-138 purified plasma cells from a newly diag...
# GSM1336389  CD-138 purified plasma cells from a newly diag...
# GSM1336390  CD-138 purified plasma cells from a newly diag...
# GSM1336391  CD-138 purified plasma cells from a newly diag...
# GSM1336392  CD-138 purified plasma cells from a newly diag...
# GSM1336393  CD-138 purified plasma cells from a newly diag...
# GSM1336394  CD-138 purified plasma cells from a newly diag...
# GSM1336395  CD-138 purified plasma cells from a newly diag...
# GSM1336396  CD-138 purified plasma cells from a newly diag...
# GSM1336397  CD-138 purified plasma cells from a newly diag...
# GSM1336398  CD-138 purified plasma cells from a newly diag...
# GSM1336399  CD-138 purified plasma cells from a newly diag...
# GSM1336400  CD-138 purified plasma cells from a newly diag...
# GSM1336401  CD-138 purified plasma cells from a newly diag...
# GSM1336402  CD-138 purified plasma cells from a newly diag...
# GSM1336403  CD-138 purified plasma cells from a newly diag...
# GSM1336404  CD-138 purified plasma cells from a newly diag...
# GSM1336405  CD-138 purified plasma cells from a newly diag...
# GSM1336406  CD-138 purified plasma cells from a newly diag...
# GSM1336407  CD-138 purified plasma cells from a newly diag...
# GSM1336408  CD-138 purified plasma cells from a newly diag...
# GSM1336409  CD-138 purified plasma cells from a newly diag...
# GSM1336410  CD-138 purified plasma cells from a newly diag...
# GSM1336411  CD-138 purified plasma cells from a newly diag...
# ...                                                       ...
# GSM1336419  CD-138 purified plasma cells from a newly diag...
# GSM1336420  CD-138 purified plasma cells from a newly diag...
# GSM1336421  CD-138 purified plasma cells from a newly diag...
# GSM1336422  CD-138 purified plasma cells from a newly diag...
# GSM1336423  CD-138 purified plasma cells from a newly diag...
# GSM1336424  CD-138 purified plasma cells from a newly diag...
# GSM1336425  CD-138 purified plasma cells from a newly diag...
# GSM1336426  CD-138 purified plasma cells from a newly diag...
# GSM1336427  CD-138 purified plasma cells from a newly diag...
# GSM1336428  CD-138 purified plasma cells from a newly diag...
# GSM1336429  CD-138 purified plasma cells from a newly diag...
# GSM1336430  CD-138 purified plasma cells from a newly diag...
# GSM1336431  CD-138 purified plasma cells from a newly diag...
# GSM1336432  CD-138 purified plasma cells from a newly diag...
# GSM1336433  CD-138 purified plasma cells from a newly diag...
# GSM1336434  CD-138 purified plasma cells from a newly diag...
# GSM1336435  CD-138 purified plasma cells from a newly diag...
# GSM1336436  CD-138 purified plasma cells from a newly diag...
# GSM1336437  CD-138 purified plasma cells from a newly diag...
# GSM1336438  CD-138 purified plasma cells from a newly diag...
# GSM1336439  CD-138 purified plasma cells from a newly diag...
# GSM1336440  CD-138 purified plasma cells from a newly diag...
# GSM1336441  CD-138 purified plasma cells from a newly diag...
# GSM1336442  CD-138 purified plasma cells from a newly diag...
# GSM1336443  CD-138 purified plasma cells from a newly diag...
# GSM1336444  CD-138 purified plasma cells from a newly diag...
# GSM1336445  CD-138 purified plasma cells from a newly diag...
# GSM1336446  CD-138 purified plasma cells from a newly diag...
# GSM1336447  CD-138 purified plasma cells from a newly diag...
# GSM1336448  CD-138 purified plasma cells from a newly diag...
#
#                                           title
# GSM
# GSM1336382  ifm67_01_VELCADE MM_6199_3_Stable_1
# GSM1336383  ifm67_02_VELCADE MM_6159_3_Stable_1
# GSM1336384    ifm67_03_VELCADE MM_6145_3_RCEP_1
# GSM1336385    ifm67_04_VELCADE MM_6073_3_Prog_1
# GSM1336386    ifm67_05_VELCADE MM_6041_3_RMin_1
# GSM1336387    ifm67_06_VELCADE MM_5994_3_RCEP_1
# GSM1336388    ifm67_07_VELCADE MM_5843_3_RCIF_1
# GSM1336389    ifm67_08_VELCADE MM_5809_3_Prog_1
# GSM1336390    ifm67_09_VELCADE MM_5745_3_RCIF_1
# GSM1336391    ifm67_10_VELCADE MM_5735_3_Prog_1
# GSM1336392    ifm67_11_VELCADE MM_5694_3_RCIF_1
# GSM1336393  ifm67_12_VELCADE MM_5682_3_Stable_1
# GSM1336394    ifm67_13_VELCADE MM_5664_3_RCEP_1
# GSM1336395    ifm67_14_VELCADE MM_5614_3_Prog_1
# GSM1336396    ifm67_15_VELCADE MM_5609_3_RCIF_1
# GSM1336397    ifm67_16_VELCADE MM_5572_3_RCEP_1
# GSM1336398    ifm67_17_VELCADE MM_5552_3_RMin_1
# GSM1336399    ifm67_18_VELCADE MM_5549_3_RCIF_1
df["drug"] = "Cisplatin"
cols = df.columns.values
df["response"] = "R"
df.loc[df["cisplatin response (complete response or incomplete response)"] == "CR","response"] = "S"
df = df.loc[:,["drug","response"] + list(cols)]
df.to_csv("../raw_data/response/GSE23554_response.tsv",sep ="\t")
df
# Out:
#                 drug response  \
# GSM
# GSM577823  Cisplatin        R
# GSM577824  Cisplatin        R
# GSM577825  Cisplatin        R
# GSM577826  Cisplatin        S
# GSM577827  Cisplatin        S
# GSM577828  Cisplatin        S
# GSM577829  Cisplatin        R
# GSM577830  Cisplatin        R
# GSM577831  Cisplatin        R
# GSM577832  Cisplatin        R
# GSM577833  Cisplatin        S
# GSM577834  Cisplatin        S
# GSM577835  Cisplatin        S
# GSM577836  Cisplatin        S
# GSM577837  Cisplatin        R
# GSM577838  Cisplatin        S
# GSM577839  Cisplatin        S
# GSM577840  Cisplatin        S
# GSM577841  Cisplatin        S
# GSM577842  Cisplatin        S
# GSM577843  Cisplatin        S
# GSM577844  Cisplatin        S
# GSM577845  Cisplatin        S
# GSM577846  Cisplatin        R
# GSM577847  Cisplatin        S
# GSM577848  Cisplatin        R
# GSM577849  Cisplatin        S
# GSM577850  Cisplatin        S
#
#           cisplatin response (complete response or incomplete response)  \
# GSM
# GSM577823                                                 IR
# GSM577824                                                 IR
# GSM577825                                                 IR
# GSM577826                                                 CR
# GSM577827                                                 CR
# GSM577828                                                 CR
# GSM577829                                                 IR
# GSM577830                                                 IR
# GSM577831                                                 IR
# GSM577832                                                 IR
# GSM577833                                                 CR
# GSM577834                                                 CR
# GSM577835                                                 CR
# GSM577836                                                 CR
# GSM577837                                                 IR
# GSM577838                                                 CR
# GSM577839                                                 CR
# GSM577840                                                 CR
# GSM577841                                                 CR
# GSM577842                                                 CR
# GSM577843                                                 CR
# GSM577844                                                 CR
# GSM577845                                                 CR
# GSM577846                                                 IR
# GSM577847                                                 CR
# GSM577848                                                 IR
# GSM577849                                                 CR
# GSM577850                                                 CR
#
#           debulking grade overall survival in days  \
# GSM
# GSM577823         S     3                      313
# GSM577824         S     2                      760
# GSM577825         S     3                      540
# GSM577826         S     3                     3268
# GSM577827         O     3                     5765
# GSM577828         S     3                     3399
# GSM577829         O     3                     1153
# GSM577830         S     2                      184
# GSM577831         O     3                       73
# GSM577832         S     3                      151
# GSM577833         O     1                     2276
# GSM577834         O     3                      177
# GSM577835         O     2                     2420
# GSM577836         S     2                      252
# GSM577837         S     3                      391
# GSM577838         O     3                     1398
# GSM577839         O     3                     1207
# GSM577840         O     3                     1594
# GSM577841         O     2                     2163
# GSM577842         S     3                      934
# GSM577843         O     2                     1979
# GSM577844         S     3                     1588
# GSM577845         S     3                     4288
# GSM577846         O     3                      399
# GSM577847         S     2                      852
# GSM577848         O     3                     1207
# GSM577849         S     1                     1598
# GSM577850        NA     2                     1123
#
#                                            source  \
# GSM
# GSM577823  advanced-stage serous epithelial OVCAs
# GSM577824  advanced-stage serous epithelial OVCAs
# GSM577825  advanced-stage serous epithelial OVCAs
# GSM577826  advanced-stage serous epithelial OVCAs
# GSM577827  advanced-stage serous epithelial OVCAs
# GSM577828  advanced-stage serous epithelial OVCAs
# GSM577829  advanced-stage serous epithelial OVCAs
# GSM577830  advanced-stage serous epithelial OVCAs
# GSM577831  advanced-stage serous epithelial OVCAs
# GSM577832  advanced-stage serous epithelial OVCAs
# GSM577833  advanced-stage serous epithelial OVCAs
# GSM577834  advanced-stage serous epithelial OVCAs
# GSM577835  advanced-stage serous epithelial OVCAs
# GSM577836  advanced-stage serous epithelial OVCAs
# GSM577837  advanced-stage serous epithelial OVCAs
# GSM577838  advanced-stage serous epithelial OVCAs
# GSM577839  advanced-stage serous epithelial OVCAs
# GSM577840  advanced-stage serous epithelial OVCAs
# GSM577841  advanced-stage serous epithelial OVCAs
# GSM577842  advanced-stage serous epithelial OVCAs
# GSM577843  advanced-stage serous epithelial OVCAs
# GSM577844  advanced-stage serous epithelial OVCAs
# GSM577845  advanced-stage serous epithelial OVCAs
# GSM577846  advanced-stage serous epithelial OVCAs
# GSM577847  advanced-stage serous epithelial OVCAs
# GSM577848  advanced-stage serous epithelial OVCAs
# GSM577849  advanced-stage serous epithelial OVCAs
# GSM577850  advanced-stage serous epithelial OVCAs
#
#                                    title vital status       drug
# GSM
# GSM577823  Ovarian Cancer - Sample D1462         Dead  Cisplatin
# GSM577824  Ovarian Cancer - Sample D1858         Dead  Cisplatin
# GSM577825  Ovarian Cancer - Sample D2147         Dead  Cisplatin
# GSM577826  Ovarian Cancer - Sample D2159        Alive  Cisplatin
# GSM577827  Ovarian Cancer - Sample D2171        Alive  Cisplatin
# GSM577828  Ovarian Cancer - Sample D2247         Dead  Cisplatin
# GSM577829  Ovarian Cancer - Sample D2251         Dead  Cisplatin
# GSM577830  Ovarian Cancer - Sample D2287         Dead  Cisplatin
# GSM577831  Ovarian Cancer - Sample D2443        Alive  Cisplatin
# GSM577832  Ovarian Cancer - Sample D2457         Dead  Cisplatin
# GSM577833  Ovarian Cancer - Sample D2528        Alive  Cisplatin
# GSM577834  Ovarian Cancer - Sample D2578        Alive  Cisplatin
# GSM577835  Ovarian Cancer - Sample D2612        Alive  Cisplatin
# GSM577836  Ovarian Cancer - Sample D2622        Alive  Cisplatin
# GSM577837  Ovarian Cancer - Sample D2651         Dead  Cisplatin
# GSM577838  Ovarian Cancer - Sample D2679         Dead  Cisplatin
# GSM577839  Ovarian Cancer - Sample D2711        Alive  Cisplatin
# GSM577840  Ovarian Cancer - Sample D2732        Alive  Cisplatin
# GSM577841  Ovarian Cancer - Sample D2734        Alive  Cisplatin
# GSM577842  Ovarian Cancer - Sample D2736        Alive  Cisplatin
# GSM577843  Ovarian Cancer - Sample D2775        Alive  Cisplatin
# GSM577844  Ovarian Cancer - Sample D2791        Alive  Cisplatin
# GSM577845  Ovarian Cancer - Sample M1777        Alive  Cisplatin
# GSM577846  Ovarian Cancer - Sample M2241         Dead  Cisplatin
# GSM577847  Ovarian Cancer - Sample M3035         Dead  Cisplatin
# GSM577848  Ovarian Cancer - Sample M3705         Dead  Cisplatin
# GSM577849  Ovarian Cancer - Sample M4171         Dead  Cisplatin
# GSM577850   Ovarian Cancer - Sample M897         Dead  Cisplatin

# %%
df.groupby("response").size()
# Out:
# response
# R    10
# S    18
# dtype: int64
